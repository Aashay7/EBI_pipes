# %%
## Links : https://www.ebi.ac.uk/scxa/experiments?species=homo%20sapiens
## Swagger Docs : https://www.ebi.ac.uk/ebisearch/swagger.ebi
## Download : https://www.ebi.ac.uk/gxa/sc/experiments/E-HCAD-30/downloads
## Main URL : https://www.ebi.ac.uk/gxa/sc/experiments?species=%22homo%20sapiens%22
## Webinar  : https://www.ebi.ac.uk/training/online/courses/embl-ebi-programmatically/ebi-search-programmatically/

# %%
import json
import requests
import numpy as np
import pandas as pd

# %%
domain = 'sc-experiments'
EBI_ENDPOINT = "https://www.ebi.ac.uk/ebisearch/ws/rest/" + domain
parameters = {}
query = 'tp53'
headers = {'Accept': 'application/json'}
parameters = {'species' : 'homo sapiens', 'size' : 5}
response = requests.get(EBI_ENDPOINT, headers=headers, params=parameters)
response.raise_for_status()

# %%
data = response.json()

# %%
print(json.dumps(data, indent=4))
# Out:
# {
#     "domains": [
#         {
#             "id": "sc-experiments",
#             "name": "Single Cell Expression Atlas Experiments",
#             "description": "A semantically enriched database of publicly available single cell gene and transcript expression data. The data is re-analysed in-house to detect genes showing inte\n\t\tresting baseline expression patterns under the conditions of the original experiment.",
#             "indexInfos": [
#                 {
#                     "name": "Number of entries",
#                     "value": "229"
#                 },
#                 {
#                     "name": "Last modification date",
#                     "value": "Thu Sep 23 02:10:32 BST 2021"
#                 },
#                 {
#                     "name": "Release date",
#                     "value": "Wed Sep 22 00:00:00 BST 2021"
#                 },
#                 {
#                     "name": "Update date",
#                     "value": "Wed Sep 22 13:02:00 BST 2021"
#                 },
#                 {
#                     "name": "URL",
#                     "value": "https://www.ebi.ac.uk/gxa/sc/home"
#                 },
#                 {
#                     "name": "Index size",
#                     "value": "79 KB"
#                 },
#                 {
#                     "name": "Index size (B)",
#                     "value": "80900"
#                 },
#                 {
#                     "name": "Hidden domain",
#                     "value": "false"
#                 },
#                 {
#                     "name": "Dictionary Availability",
#                     "value": "false"
#                 }
#             ],
#             "fieldInfos": [
#                 {
#                     "id": "$facets",
#                     "name": "$facets",
#                     "description": "Lucene internal facets field",
#                     "options": [
#                         {
#                             "name": "searchable",
#                             "value": "true"
#                         },
#                         {
#                             "name": "retrievable",
#                             "value": "false"
#                         },
#                         {
#                             "name": "sortable",
#                             "value": "false"
#                         },
#                         {
#                             "name": "facet",
#                             "value": "false"
#                         },
#                         {
#                             "name": "type",
#                             "value": "KEYWORD"
#                         },
#                         {
#                             "name": "topterms",
#                             "value": "false"
#                         },
#                         {
#                             "name": "default search field",
#                             "value": "false"
#                         }
#                     ]
#                 },
#                 {
#                     "id": "ARRAYEXPRESS",
#                     "name": "ARRAYEXPRESS",
#                     "description": "ArrayExpress (Repository of Microarray data)",
#                     "options": [
#                         {
#                             "name": "searchable",
#                             "value": "true"
#                         },
#                         {
#                             "name": "retrievable",
#                             "value": "true"
#                         },
#                         {
#                             "name": "sortable",
#                             "value": "false"
#                         },
#                         {
#                             "name": "facet",
#                             "value": "false"
#                         },
#                         {
#                             "name": "referenced domain",
#                             "value": "arrayexpress-repository"
#                         },
#                         {
#                             "name": "referenced field",
#                             "value": "acc"
#                         },
#                         {
#                             "name": "type",
#                             "value": "XREF"
#                         },
#                         {
#                             "name": "topterms",
#                             "value": "false"
#                         },
#                         {
#                             "name": "default search field",
#                             "value": "true"
#                         }
#                     ]
#                 },
#                 {
#                     "id": "celltype",
#                     "name": "celltype",
#                     "description": "Cell type",
#                     "options": [
#                         {
#                             "name": "searchable",
#                             "value": "true"
#                         },
#                         {
#                             "name": "retrievable",
#                             "value": "false"
#                         },
#                         {
#                             "name": "sortable",
#                             "value": "false"
#                         },
#                         {
#                             "name": "facet",
#                             "value": "false"
#                         },
#                         {
#                             "name": "type",
#                             "value": "TEXT"
#                         },
#                         {
#                             "name": "topterms",
#                             "value": "false"
#                         },
#                         {
#                             "name": "default search field",
#                             "value": "true"
#                         }
#                     ]
#                 },
#                 {
#                     "id": "collection",
#                     "name": "collection",
#                     "description": "Collection",
#                     "options": [
#                         {
#                             "name": "searchable",
#                             "value": "true"
#                         },
#                         {
#                             "name": "retrievable",
#                             "value": "false"
#                         },
#                         {
#                             "name": "sortable",
#                             "value": "false"
#                         },
#                         {
#                             "name": "facet",
#                             "value": "false"
#                         },
#                         {
#                             "name": "type",
#                             "value": "KEYWORD"
#                         },
#                         {
#                             "name": "topterms",
#                             "value": "false"
#                         },
#                         {
#                             "name": "default search field",
#                             "value": "true"
#                         }
#                     ]
#                 },
#                 {
#                     "id": "creation_date",
#                     "name": "creation_date",
#                     "description": "Creation date",
#                     "options": [
#                         {
#                             "name": "searchable",
#                             "value": "true"
#                         },
#                         {
#                             "name": "retrievable",
#                             "value": "true"
#                         },
#                         {
#                             "name": "sortable",
#                             "value": "false"
#                         },
#                         {
#                             "name": "facet",
#                             "value": "false"
#                         },
#                         {
#                             "name": "type",
#                             "value": "DATE"
#                         },
#                         {
#                             "name": "topterms",
#                             "value": "false"
#                         },
#                         {
#                             "name": "default search field",
#                             "value": "true"
#                         }
#                     ]
#                 },
#                 {
#                     "id": "description",
#                     "name": "description",
#                     "description": "Description",
#                     "options": [
#                         {
#                             "name": "searchable",
#                             "value": "true"
#                         },
#                         {
#                             "name": "retrievable",
#                             "value": "true"
#                         },
#                         {
#                             "name": "sortable",
#                             "value": "false"
#                         },
#                         {
#                             "name": "facet",
#                             "value": "false"
#                         },
#                         {
#                             "name": "type",
#                             "value": "TEXT"
#                         },
#                         {
#                             "name": "topterms",
#                             "value": "false"
#                         },
#                         {
#                             "name": "default search field",
#                             "value": "true"
#                         }
#                     ]
#                 },
#                 {
#                     "id": "domain_source",
#                     "name": "domain_source",
#                     "description": "Domain source",
#                     "options": [
#                         {
#                             "name": "searchable",
#                             "value": "true"
#                         },
#                         {
#                             "name": "retrievable",
#                             "value": "true"
#                         },
#                         {
#                             "name": "sortable",
#                             "value": "false"
#                         },
#                         {
#                             "name": "facet",
#                             "value": "true"
#                         },
#                         {
#                             "name": "type",
#                             "value": "KEYWORD"
#                         },
#                         {
#                             "name": "topterms",
#                             "value": "false"
#                         },
#                         {
#                             "name": "default search field",
#                             "value": "false"
#                         }
#                     ]
#                 },
#                 {
#                     "id": "factors",
#                     "name": "factors",
#                     "description": "Factors",
#                     "options": [
#                         {
#                             "name": "searchable",
#                             "value": "true"
#                         },
#                         {
#                             "name": "retrievable",
#                             "value": "true"
#                         },
#                         {
#                             "name": "sortable",
#                             "value": "false"
#                         },
#                         {
#                             "name": "facet",
#                             "value": "false"
#                         },
#                         {
#                             "name": "type",
#                             "value": "TEXT"
#                         },
#                         {
#                             "name": "topterms",
#                             "value": "false"
#                         },
#                         {
#                             "name": "default search field",
#                             "value": "true"
#                         }
#                     ]
#                 },
#                 {
#                     "id": "id",
#                     "name": "id",
#                     "description": "Identifier",
#                     "options": [
#                         {
#                             "name": "searchable",
#                             "value": "true"
#                         },
#                         {
#                             "name": "retrievable",
#                             "value": "true"
#                         },
#                         {
#                             "name": "sortable",
#                             "value": "false"
#                         },
#                         {
#                             "name": "facet",
#                             "value": "false"
#                         },
#                         {
#                             "name": "type",
#                             "value": "KEYWORD"
#                         },
#                         {
#                             "name": "topterms",
#                             "value": "false"
#                         },
#                         {
#                             "name": "default search field",
#                             "value": "true"
#                         }
#                     ]
#                 },
#                 {
#                     "id": "last_modification_date",
#                     "name": "last_modification_date",
#                     "description": "Last modification date",
#                     "options": [
#                         {
#                             "name": "searchable",
#                             "value": "true"
#                         },
#                         {
#                             "name": "retrievable",
#                             "value": "true"
#                         },
#                         {
#                             "name": "sortable",
#                             "value": "false"
#                         },
#                         {
#                             "name": "facet",
#                             "value": "false"
#                         },
#                         {
#                             "name": "type",
#                             "value": "DATE"
#                         },
#                         {
#                             "name": "topterms",
#                             "value": "false"
#                         },
#                         {
#                             "name": "default search field",
#                             "value": "true"
#                         }
#                     ]
#                 },
#                 {
#                     "id": "name",
#                     "name": "name",
#                     "description": "Name",
#                     "options": [
#                         {
#                             "name": "searchable",
#                             "value": "true"
#                         },
#                         {
#                             "name": "retrievable",
#                             "value": "true"
#                         },
#                         {
#                             "name": "sortable",
#                             "value": "false"
#                         },
#                         {
#                             "name": "facet",
#                             "value": "false"
#                         },
#                         {
#                             "name": "type",
#                             "value": "TEXT"
#                         },
#                         {
#                             "name": "topterms",
#                             "value": "false"
#                         },
#                         {
#                             "name": "default search field",
#                             "value": "true"
#                         }
#                     ]
#                 },
#                 {
#                     "id": "publication_date",
#                     "name": "publication_date",
#                     "description": "Publication date",
#                     "options": [
#                         {
#                             "name": "searchable",
#                             "value": "true"
#                         },
#                         {
#                             "name": "retrievable",
#                             "value": "true"
#                         },
#                         {
#                             "name": "sortable",
#                             "value": "true"
#                         },
#                         {
#                             "name": "facet",
#                             "value": "true"
#                         },
#                         {
#                             "name": "type",
#                             "value": "DATE"
#                         },
#                         {
#                             "name": "topterms",
#                             "value": "false"
#                         },
#                         {
#                             "name": "default search field",
#                             "value": "true"
#                         }
#                     ]
#                 },
#                 {
#                     "id": "species",
#                     "name": "species",
#                     "description": "Species",
#                     "options": [
#                         {
#                             "name": "searchable",
#                             "value": "true"
#                         },
#                         {
#                             "name": "retrievable",
#                             "value": "true"
#                         },
#                         {
#                             "name": "sortable",
#                             "value": "false"
#                         },
#                         {
#                             "name": "facet",
#                             "value": "false"
#                         },
#                         {
#                             "name": "type",
#                             "value": "TEXT"
#                         },
#                         {
#                             "name": "topterms",
#                             "value": "false"
#                         },
#                         {
#                             "name": "default search field",
#                             "value": "true"
#                         }
#                     ]
#                 },
#                 {
#                     "id": "technology",
#                     "name": "technology",
#                     "description": "Technology",
#                     "options": [
#                         {
#                             "name": "searchable",
#                             "value": "true"
#                         },
#                         {
#                             "name": "retrievable",
#                             "value": "false"
#                         },
#                         {
#                             "name": "sortable",
#                             "value": "false"
#                         },
#                         {
#                             "name": "facet",
#                             "value": "false"
#                         },
#                         {
#                             "name": "type",
#                             "value": "TEXT"
#                         },
#                         {
#                             "name": "topterms",
#                             "value": "false"
#                         },
#                         {
#                             "name": "default search field",
#                             "value": "true"
#                         }
#                     ]
#                 }
#             ]
#         }
#     ]
# }
